# %% [markdown]
# ### **Create virtual environment** -> <u>run only if this is the first time you start the tool<u>

# %%
# !python src/setup_venv.py

# %% [markdown]
# ---

# %% [markdown]
# ### **Check virtual environment**

# %%
# from src.Functions_General import check_venv_kernel
# check_venv_kernel(venv_name='.venv')

# %% [markdown]
# ---

# %% [markdown]
# ### **Import all functions and libraries**

# %%
from src.Functions_General import *
from src.Functions_Energy_Model import *
from src.Functions_Financial_Model import *
from src.Functions_Load_Emulator_and_DSM import *
from src.Functions_Load_Emulator_v2 import *

from src.hvac_functions.classes.cerClasses import Cacer
from src.hvac_functions.functions.non_optimized import non_optimized, adding_HVAC_energy_consumption
from src.hvac_functions.functions.weather_data import *

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## **External inputs to set before to run the simulation**
#
# Before to run the simulation be sure to have set correctly the following input files:
#
# - config.yml [[link yaml](config.yml)]
#
# - users CACER.xlsx [[link excel](users%20CACER.xlsx)]
#
# - inputs_FM.xlsx [[link excel](files/inputs_FM.xlsx)]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## **Initializing CACER configuration**

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **1. Generating the calendar file**

# %%
generate_calendar()

# %% [markdown]
# ---

# %% [markdown]
# ### **2. Generating the yaml and csv files with all the inputs of the CACER configuration**

# %%
initialization_users()

# %% [markdown]
# ---

# %% [markdown]
# ### **3. Generating the emulated load profile of the users**

# %%
run_load_emulator()

# %% [markdown]
# ---

# %% [markdown]
# ### **4. Generating all load profile of the users (domestic users, commercial users, industrial users, etc.)**

# %%
load_profile_all_users()

# %% [markdown]
# ---

# %% [markdown]
# ### **5. Generating thermal load profile and electric load profile for air conditioning of the users**

# %%
# Generate weather data for a typical meteorological year (TMY) and for future scenarios
weather_data_generator()
future_weather_data_generator()
select_years_future_weather_data()

# %%
# Create Cacer instance
Cacer_1  = suppress_printing(Cacer, './')

# Run non-optimized simulation
df_total_results = non_optimized(Cacer_1)

# %%
adding_HVAC_energy_consumption()

# %% [markdown]
# ---

# %% [markdown]
# ### **6. Generating productivity of the photovoltaic generators**

# %%
simulate_configuration_productivity()

# %% [markdown]
# ---

# %% [markdown]
# ### **7. Generating all energy flows of the single users**

# %%
CACER_energy_flows()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## **Simulate CACER configuration**

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **8. Calculate the electricity bills for each user types**

# %%
create_users_bill()

# %% [markdown]
# ---

# %% [markdown]
# ### **9. Setting name and type of the configuration and editing of the incentive repartition**

# %%
case_denomination = "prova"
CACER_type = "CER" # CER; AUD; AID; NO_CACER
repartition_scheme = "Egualitario" # Egualitario; Prosumer; PNRR; Equitario; Misto CER; Misto AUC; Misto - ESCo; Social Fund; Misto - Social Fund; Misto - Social Fund 2; Misto - Social Fund PA; Misto - PA; CACER

setting_CACER_scenario(case_denomination, CACER_type, repartition_scheme)

# %% [markdown]
# ---

# %% [markdown]
# ### **10. Calculate CACER energy shared**

# %%
CACER_shared_energy()

# %% [markdown]
# ---

# %% [markdown]
# ### **11. Calculate energy sold revenues**

# %%
RID_calculation()

# %% [markdown]
# ---

# %% [markdown]
# ### **12. Aggregate bills costs and energy sold revenues for the entire CACER configuration**

# %%
aggregate_CACER_bills()

# %%
aggregate_CACER_RID()

# %% [markdown]
# ---

# %% [markdown]
# ### **13. Generating the xlsx and csv files with all the financial inputs of the CACER configuration**

# %%
FM_initialization()

# %% [markdown]
# ---

# %% [markdown]
# ### **14. Calculate incentives revenues**

# %%
incentives()

# %% [markdown]
# ---

# %% [markdown]
# ### **15. All the economic cash flows for each users and for each stakeholders are calculated**

# %%
cash_flows_for_all_plants() # plants first...

# %%
cash_flows_for_all_users() # ...then users...

# %% [markdown]
# ---

# %% [markdown]
# ### **16. All the economic cash flows are aggregated for the project and for the CACER configuration (<u>for single primary station</u>)**

# %%
aggregate_FM() # ...then configurations!

# %% [markdown]
# ---

# %% [markdown]
# ### **16.1 The simulation results are organized for the export and for the creation of the report**

# %%
organize_simulation_results_for_reporting()

# %% [markdown]
# ---

# %% [markdown]
# ### **16.2 Creating the report with results**

# %%
# %run Reporting.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ### **16.3 Creating the report with results**

# %%
save_simulation_results(simulation_name = case_denomination)

# %% [markdown]
# ---

# %% [markdown]
# ### **17. Killing all excel processes in background**

# %%
kill_excel_processes()

# %% [markdown]
# ---
# ---
